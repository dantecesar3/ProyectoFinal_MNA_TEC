# %% [markdown]
# # EDA para documentos en el reconomiento de variables para automatización

# %% [markdown]
# ## 1. Preparación

# %% [markdown]
# ### 1.1. Instalación de dependencias

# %%
# %pip install PyPDF2
# %pip install pandas
# %pip install seaborn
# %pip install WordCloud
# %pip install sklearn
# Out:
# Requirement already satisfied: PyPDF2 in c:\users\rafap\documents\rafa\utesm\ultimotrimestre\proyecto integrador\repository\.env\lib\site-packages (3.0.1)
# Requirement already satisfied: typing_extensions>=3.10.0.0 in c:\users\rafap\documents\rafa\utesm\ultimotrimestre\proyecto integrador\repository\.env\lib\site-packages (from PyPDF2) (4.12.2)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 25.0 is available.
# You should consider upgrading via the 'c:\Users\rafap\Documents\Rafa\UTESM\UltimoTrimestre\Proyecto integrador\Repository\.env\Scripts\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: pandas in c:\users\rafap\documents\rafa\utesm\ultimotrimestre\proyecto integrador\repository\.env\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\rafap\documents\rafa\utesm\ultimotrimestre\proyecto integrador\repository\.env\lib\site-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\rafap\documents\rafa\utesm\ultimotrimestre\proyecto integrador\repository\.env\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rafap\documents\rafa\utesm\ultimotrimestre\proyecto integrador\repository\.env\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\rafap\documents\rafa\utesm\ultimotrimestre\proyecto integrador\repository\.env\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\rafap\documents\rafa\utesm\ultimotrimestre\proyecto integrador\repository\.env\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 25.0 is available.
# You should consider upgrading via the 'c:\Users\rafap\Documents\Rafa\UTESM\UltimoTrimestre\Proyecto integrador\Repository\.env\Scripts\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: seaborn in c:\users\rafap\documents\rafa\utesm\ultimotrimestre\proyecto integrador\repository\.env\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\rafap\documents\rafa\utesm\ultimotrimestre\proyecto integrador\repository\.env\lib\site-packages (from seaborn) (2.0.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\rafap\documents\rafa\utesm\ultimotrimestre\proyecto integrador\repository\.env\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\rafap\documents\rafa\utesm\ultimotrimestre\proyecto integrador\repository\.env\lib\site-packages (from seaborn) (3.9.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rafap\documents\rafa\utesm\ultimotrimestre\proyecto integrador\repository\.env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\rafap\documents\rafa\utesm\ultimotrimestre\proyecto integrador\repository\.env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\rafap\documents\rafa\utesm\ultimotrimestre\proyecto integrador\repository\.env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (6.5.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\rafap\documents\rafa\utesm\ultimotrimestre\proyecto integrador\repository\.env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rafap\documents\rafa\utesm\ultimotrimestre\proyecto integrador\repository\.env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\rafap\documents\rafa\utesm\ultimotrimestre\proyecto integrador\repository\.env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\rafap\documents\rafa\utesm\ultimotrimestre\proyecto integrador\repository\.env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rafap\documents\rafa\utesm\ultimotrimestre\proyecto integrador\repository\.env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.55.8)
# Requirement already satisfied: pillow>=8 in c:\users\rafap\documents\rafa\utesm\ultimotrimestre\proyecto integrador\repository\.env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\rafap\documents\rafa\utesm\ultimotrimestre\proyecto integrador\repository\.env\lib\site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn) (3.21.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rafap\documents\rafa\utesm\ultimotrimestre\proyecto integrador\repository\.env\lib\site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\rafap\documents\rafa\utesm\ultimotrimestre\proyecto integrador\repository\.env\lib\site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\rafap\documents\rafa\utesm\ultimotrimestre\proyecto integrador\repository\.env\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 25.0 is available.
# You should consider upgrading via the 'c:\Users\rafap\Documents\Rafa\UTESM\UltimoTrimestre\Proyecto integrador\Repository\.env\Scripts\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: WordCloud in c:\users\rafap\documents\rafa\utesm\ultimotrimestre\proyecto integrador\repository\.env\lib\site-packages (1.9.4)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\rafap\documents\rafa\utesm\ultimotrimestre\proyecto integrador\repository\.env\lib\site-packages (from WordCloud) (2.0.2)
# Requirement already satisfied: matplotlib in c:\users\rafap\documents\rafa\utesm\ultimotrimestre\proyecto integrador\repository\.env\lib\site-packages (from WordCloud) (3.9.4)
# Requirement already satisfied: pillow in c:\users\rafap\documents\rafa\utesm\ultimotrimestre\proyecto integrador\repository\.env\lib\site-packages (from WordCloud) (11.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rafap\documents\rafa\utesm\ultimotrimestre\proyecto integrador\repository\.env\lib\site-packages (from matplotlib->WordCloud) (1.3.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\rafap\documents\rafa\utesm\ultimotrimestre\proyecto integrador\repository\.env\lib\site-packages (from matplotlib->WordCloud) (6.5.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rafap\documents\rafa\utesm\ultimotrimestre\proyecto integrador\repository\.env\lib\site-packages (from matplotlib->WordCloud) (4.55.8)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rafap\documents\rafa\utesm\ultimotrimestre\proyecto integrador\repository\.env\lib\site-packages (from matplotlib->WordCloud) (2.9.0.post0)
# Requirement already satisfied: packaging>=20.0 in c:\users\rafap\documents\rafa\utesm\ultimotrimestre\proyecto integrador\repository\.env\lib\site-packages (from matplotlib->WordCloud) (24.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\rafap\documents\rafa\utesm\ultimotrimestre\proyecto integrador\repository\.env\lib\site-packages (from matplotlib->WordCloud) (0.12.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\rafap\documents\rafa\utesm\ultimotrimestre\proyecto integrador\repository\.env\lib\site-packages (from matplotlib->WordCloud) (3.2.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\rafap\documents\rafa\utesm\ultimotrimestre\proyecto integrador\repository\.env\lib\site-packages (from matplotlib->WordCloud) (1.4.7)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\rafap\documents\rafa\utesm\ultimotrimestre\proyecto integrador\repository\.env\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->WordCloud) (3.21.0)
# Requirement already satisfied: six>=1.5 in c:\users\rafap\documents\rafa\utesm\ultimotrimestre\proyecto integrador\repository\.env\lib\site-packages (from python-dateutil>=2.7->matplotlib->WordCloud) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 25.0 is available.
# You should consider upgrading via the 'c:\Users\rafap\Documents\Rafa\UTESM\UltimoTrimestre\Proyecto integrador\Repository\.env\Scripts\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: sklearn in c:\users\rafap\documents\rafa\utesm\ultimotrimestre\proyecto integrador\repository\.env\lib\site-packages (0.0)
# Requirement already satisfied: scikit-learn in c:\users\rafap\documents\rafa\utesm\ultimotrimestre\proyecto integrador\repository\.env\lib\site-packages (from sklearn) (1.6.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\rafap\documents\rafa\utesm\ultimotrimestre\proyecto integrador\repository\.env\lib\site-packages (from scikit-learn->sklearn) (3.5.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\rafap\documents\rafa\utesm\ultimotrimestre\proyecto integrador\repository\.env\lib\site-packages (from scikit-learn->sklearn) (1.4.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\rafap\documents\rafa\utesm\ultimotrimestre\proyecto integrador\repository\.env\lib\site-packages (from scikit-learn->sklearn) (1.13.1)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\rafap\documents\rafa\utesm\ultimotrimestre\proyecto integrador\repository\.env\lib\site-packages (from scikit-learn->sklearn) (2.0.2)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 25.0 is available.
# You should consider upgrading via the 'c:\Users\rafap\Documents\Rafa\UTESM\UltimoTrimestre\Proyecto integrador\Repository\.env\Scripts\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# ### 1.2. Importación de librerias

# %%
import PyPDF2
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from wordcloud import WordCloud,STOPWORDS
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import PCA

# %% [markdown]
# ### 1.3. Extracción de datos PDFs a Dataframe

# %%
def extract_text_from_pdf(pdf_path):
    with open(pdf_path, 'rb') as file:
        reader = PyPDF2.PdfReader(file)
        text = ""
        for page in reader.pages:
            text += page.extract_text()
    return text

# %%
# Directorio con tus PDFs
pdf_folder = "datos"
data = []

for filename in os.listdir(pdf_folder):
    if filename.lower().endswith('.pdf'):
        file_path = os.path.join(pdf_folder, filename)
        text = extract_text_from_pdf(file_path)
        # Aquí podrías aplicar algún procesamiento adicional para extraer campos específicos usando regex, NLP, etc.
        data.append({
            "filename": filename,
            "text": text,
            "num_caracteres": len(text)
        })

# Convertir la lista de diccionarios a DataFrame
df = pd.DataFrame(data)
print(df.head())
# Out:
#                                             filename  \
# 0  0035_FNA_FSW_011_2024_Técnico.NetMobile_WI_202...
# 1     0080_FNA_ FSW_011_2024_ BolsaHoras firmada.pdf
# 2  0083_FNA_FSW_011_2024_156900_FacturaciónElect...
# 3  0084_ FNA_FSW_011_2024_ResumenActa_Horas_Extra...
# 4  0085_FNA_FSW_011_2024_Soporte_StandBy_31122024...
#
#                                                 text  num_caracteres
# 0   FORMATO ACTA DE REUNIÓN  Código  \nGE-GP-FO-\...            8071
# 1   FORMATO ACTA DE REUNIÓN  Código  \nGE-GP-FO-0...           12038
# 2   FORMATO ACTA DE REUNIÓN  Código  \nGE-GP-FO-0...            9471
# 3   FORMATO ACTA DE REUNIÓN  Código  \nGE-GP-FO-0...            6861
# 4   FORMATO ACTA DE REUNIÓN  Código  \nGE-GP-FO-0...            8791

# %% [markdown]
# ## 2. Aplicación del EDA

# %% [markdown]
# ### 2.1. Análisis general del dataframe

# %%
# Información básica
print(df.info())

# Estadísticas descriptivas (en este caso, por ejemplo, la longitud del texto)
print(df['num_caracteres'].describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   filename        7 non-null      object
#  1   text            7 non-null      object
#  2   num_caracteres  7 non-null      int64
# dtypes: int64(1), object(2)
# memory usage: 296.0+ bytes
# None
# count        7.000000
# mean     10850.857143
# std       4806.732481
# min       6861.000000
# 25%       8431.000000
# 50%       9471.000000
# 75%      10812.000000
# max      21138.000000
# Name: num_caracteres, dtype: float64

# %% [markdown]
# ### 2.2. Detección de Valores Faltantes

# %%
# Verificar si hay valores nulos
print(df.isnull().sum())

# Visualización de valores faltantes (opcional, con seaborn o matplotlib)

sns.heatmap(df.isnull(), cbar=False, yticklabels=False, cmap='viridis')
plt.title("Mapa de valores faltantes")
plt.show()
# Out:
# filename          0
# text              0
# num_caracteres    0
# dtype: int64

# %% [markdown]
# ### 2.3. Análisis de Distribuciones

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['num_caracteres'], bins=30, kde=True)
plt.title("Distribución de la longitud del texto en los PDFs")
plt.xlabel("Número de caracteres")
plt.ylabel("Frecuencia")
plt.show()

# %% [markdown]
# ### 2.4. Análisis de Contenido

# %%
# Definir stopwords en español adicionales
spanish_stopwords = set(STOPWORDS)
# Añadir algunos artículos y otras palabras comunes en español
spanish_stopwords.update([
    "el", "la", "los", "las", "de", "del", "al", "a", "en", "y", "que", "un", "una", "unos", "unas",
    "por", "con", "para", "como", "es", "se", "no", "su", "lo", "más", "pero", "sus", "le", "ha", "me",
    "si", "sin", "sobre", "este", "ya", "entre", "cuando", "todo", "esta", "ser", "son", "dos"
])

# Unir todos los textos extraídos para generar una nube de palabras
all_text = " ".join(df['text'].tolist())

wordcloud = WordCloud(
    width=800,
    height=400, 
    stopwords=spanish_stopwords,
    background_color='white',
    collocations=False 
    ).generate(all_text)

plt.figure(figsize=(15, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title("Nube de palabras del contenido extraído")
plt.show()

# %% [markdown]
# ## 3. Ingeniería de caracteristicas

# %% [markdown]
# ### 3.1. Generación de Características Basadas en Texto

# %%
tfidf_vectorizer = TfidfVectorizer(
    stop_words=list(spanish_stopwords),  # Conversión a lista
    max_df=0.85,                         # Ignorar términos muy frecuentes
    min_df=2                             # Considerar solo términos que aparezcan en al menos 2 documentos
)

# Transformar la columna 'text' en una matriz TF-IDF
tfidf_matrix = tfidf_vectorizer.fit_transform(df['text'])
print("\nDimensión de la matriz TF-IDF:", tfidf_matrix.shape)
# Out:
# Dimensión de la matriz TF-IDF: (7, 538)
# c:\Users\rafap\Documents\Rafa\UTESM\UltimoTrimestre\Proyecto integrador\Repository\.env\lib\site-packages\sklearn\feature_extraction\text.py:402: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['aren', 'couldn', 'didn', 'doesn', 'don', 'hadn', 'hasn', 'haven', 'isn', 'let', 'll', 'mustn', 're', 'shan', 'shouldn', 've', 'wasn', 'weren', 'won', 'wouldn'] not in stop_words.
#   warnings.warn(

# %%
# ==========================================================
# 4. (Opcional) Reducción de Dimensionalidad con PCA
# ==========================================================

# Determinar el número máximo de componentes que se pueden extraer
# Esto es el mínimo entre el número de muestras y el número de características
max_componentes = min(tfidf_matrix.shape[0], tfidf_matrix.shape[1])

# Si deseas usar hasta 100 componentes y están disponibles, de lo contrario usa el máximo posible
n_componentes = 100 if max_componentes >= 100 else max_componentes

from sklearn.decomposition import PCA
pca = PCA(n_components=n_componentes, random_state=42)

# Convertir la matriz dispersa a array y aplicar PCA
tfidf_pca = pca.fit_transform(tfidf_matrix.toarray())
print("Dimensión de la matriz TF-IDF después de PCA:", tfidf_pca.shape)

# Crear un DataFrame con las componentes principales
tfidf_pca_df = pd.DataFrame(tfidf_pca, columns=[f'pca_{i+1}' for i in range(n_componentes)])
# Out:
# Dimensión de la matriz TF-IDF después de PCA: (7, 7)

# %%
# ==========================================================
# 5. Integración de Todas las Características
# ==========================================================

# Combinar el DataFrame original con las nuevas variables y las componentes principales del TF-IDF
df_features = pd.concat([df.reset_index(drop=True), tfidf_pca_df.reset_index(drop=True)], axis=1)
print("\nDataFrame final con características de ingeniería:")
print(df_features.head())
# Out:
# DataFrame final con características de ingeniería:
#                                             filename  \
# 0  0035_FNA_FSW_011_2024_Técnico.NetMobile_WI_202...
# 1     0080_FNA_ FSW_011_2024_ BolsaHoras firmada.pdf
# 2  0083_FNA_FSW_011_2024_156900_FacturaciónElect...
# 3  0084_ FNA_FSW_011_2024_ResumenActa_Horas_Extra...
# 4  0085_FNA_FSW_011_2024_Soporte_StandBy_31122024...
#
#                                                 text  num_caracteres  \
# 0   FORMATO ACTA DE REUNIÓN  Código  \nGE-GP-FO-\...            8071
# 1   FORMATO ACTA DE REUNIÓN  Código  \nGE-GP-FO-0...           12038
# 2   FORMATO ACTA DE REUNIÓN  Código  \nGE-GP-FO-0...            9471
# 3   FORMATO ACTA DE REUNIÓN  Código  \nGE-GP-FO-0...            6861
# 4   FORMATO ACTA DE REUNIÓN  Código  \nGE-GP-FO-0...            8791
#
#       pca_1     pca_2     pca_3     pca_4     pca_5     pca_6         pca_7
# 0 -0.101671  0.533184 -0.469914  0.445700 -0.061510 -0.170691  1.546118e-16
# 1  0.530529 -0.176352 -0.312371 -0.314473 -0.439591  0.087302  1.546118e-16
# 2 -0.432877 -0.329696 -0.057991  0.249763  0.022583  0.486091  1.546118e-16
# 3 -0.565644 -0.431999  0.040627 -0.173732 -0.068005 -0.407499  1.546118e-16
# 4  0.207422  0.178227  0.761475  0.242020 -0.208515 -0.030324  1.546118e-16

# %%
# ==========================================================
# 6. Generación de la Nube de Palabras (Opcional)
# ==========================================================

# Unir todos los textos extraídos para generar una nube de palabras
all_text = " ".join(df['text'].tolist())

wordcloud = WordCloud(
    width=800,
    height=400, 
    stopwords=spanish_stopwords,  # Aquí puedes seguir usando el set si lo deseas para la nube
    background_color='white',
    collocations=False
).generate(all_text)

plt.figure(figsize=(15, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title("Nube de palabras del contenido extraído")
plt.show()

# %%
pip install Office365-REST-Python-Client
# Out:
# Collecting Office365-REST-Python-Client
#   Downloading Office365_REST_Python_Client-2.5.14-py3-none-any.whl (1.2 MB)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\rafap\documents\rafa\utesm\ultimotrimestre\proyecto integrador\repository\.env\lib\site-packages (from Office365-REST-Python-Client) (4.12.2)
# Collecting requests
#   Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Collecting msal
#   Downloading msal-1.31.1-py3-none-any.whl (113 kB)
# Requirement already satisfied: pytz in c:\users\rafap\documents\rafa\utesm\ultimotrimestre\proyecto integrador\repository\.env\lib\site-packages (from Office365-REST-Python-Client) (2025.1)
# Collecting cryptography<46,>=2.5
#   Downloading cryptography-44.0.0-cp39-abi3-win_amd64.whl (3.2 MB)
# Collecting PyJWT[crypto]<3,>=1.0.0
#   Downloading PyJWT-2.10.1-py3-none-any.whl (22 kB)
# Collecting cffi>=1.12
#   Downloading cffi-1.17.1-cp39-cp39-win_amd64.whl (181 kB)
# Collecting pycparser
#   Using cached pycparser-2.22-py3-none-any.whl (117 kB)
# Collecting idna<4,>=2.5
#   Using cached idna-3.10-py3-none-any.whl (70 kB)
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.4.1-cp39-cp39-win_amd64.whl (102 kB)
# Collecting urllib3<3,>=1.21.1
#   Downloading urllib3-2.3.0-py3-none-any.whl (128 kB)
# Collecting certifi>=2017.4.17
#   Downloading certifi-2025.1.31-py3-none-any.whl (166 kB)
# Installing collected packages: pycparser, cffi, urllib3, PyJWT, idna, cryptography, charset-normalizer, certifi, requests, msal, Office365-REST-Python-Client
# Successfully installed Office365-REST-Python-Client-2.5.14 PyJWT-2.10.1 certifi-2025.1.31 cffi-1.17.1 charset-normalizer-3.4.1 cryptography-44.0.0 idna-3.10 msal-1.31.1 pycparser-2.22 requests-2.32.3 urllib3-2.3.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 25.0 is available.
# You should consider upgrading via the 'c:\Users\rafap\Documents\Rafa\UTESM\UltimoTrimestre\Proyecto integrador\Repository\.env\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
from office365.sharepoint.client_context import ClientContext
from office365.runtime.auth.authentication_context import AuthenticationContext

# URL del sitio SharePoint (puede ser SharePoint Online)
site_url = "https://tecmx.sharepoint.com/sites/Proyectointegrador222"
username = "a01794500@tec.mx"
password = "Cacharrero97*"

# Crear contexto de autenticación
ctx_auth = AuthenticationContext(site_url)
if ctx_auth.acquire_token_for_user(username, password):
    ctx = ClientContext(site_url, ctx_auth)
    
    # Obtener la lista o biblioteca de documentos (por ejemplo, "Documents")
    lista_documentos = ctx.web.lists.get_by_title("Documents")
    
    # Cargar los items de la lista
    items = lista_documentos.items
    ctx.load(items)
    ctx.execute_query()
    
    # Recorrer e imprimir las propiedades de cada item
    for item in items:
        print(item.properties)
else:
    print("Error de autenticación")
# Out:
# An error occurred while retrieving auth cookies from https://tecmx.sharepoint.com/_forms/default.aspx?wa=wsignin1.0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 20
#      18 items = lista_documentos.items
#      19 ctx.load(items)
# ---> 20 ctx.execute_query()
#      22 # Recorrer e imprimir las propiedades de cada item
#      23 for item in items:
#
# File c:\Users\rafap\Documents\Rafa\UTESM\UltimoTrimestre\Proyecto integrador\Repository\.env\lib\site-packages\office365\runtime\client_runtime_context.py:173, in ClientRuntimeContext.execute_query(self)
#     171 while self.has_pending_request:
#     172     qry = self._get_next_query()
# --> 173     self.pending_request().execute_query(qry)
#     174 return self
#
# File c:\Users\rafap\Documents\Rafa\UTESM\UltimoTrimestre\Proyecto integrador\Repository\.env\lib\site-packages\office365\runtime\client_request.py:37, in ClientRequest.execute_query(self, query)
#      35 try:
#      36     request = self.build_request(query)
# ---> 37     response = self.execute_request_direct(request)
#      38     self.process_response(response, query)
#      39     self.afterExecute.notify(response)
#
# File c:\Users\rafap\Documents\Rafa\UTESM\UltimoTrimestre\Proyecto integrador\Repository\.env\lib\site-packages\office365\runtime\client_request.py:46, in ClientRequest.execute_request_direct(self, request)
#      43 def execute_request_direct(self, request):
#      44     # type: (RequestOptions) -> requests.Response
#      45     """Execute the client request"""
# ---> 46     self.beforeExecute.notify(request)
#      47     if request.method == HttpMethod.Post:
#      48         if request.is_bytes or request.is_file:
#
# File c:\Users\rafap\Documents\Rafa\UTESM\UltimoTrimestre\Proyecto integrador\Repository\.env\lib\site-packages\office365\runtime\types\event_handler.py:41, in EventHandler.notify(self, *args, **kwargs)
#      39 if self._once:
#      40     self._listeners.remove(listener)
# ---> 41 listener(*args, **kwargs)
#
# File c:\Users\rafap\Documents\Rafa\UTESM\UltimoTrimestre\Proyecto integrador\Repository\.env\lib\site-packages\office365\sharepoint\client_context.py:284, in ClientContext._authenticate_request(self, request)
#     281 def _authenticate_request(self, request):
#     282     # type: (RequestOptions) -> None
#     283     """Authenticate request"""
# --> 284     self.authentication_context.authenticate_request(request)
#
# File c:\Users\rafap\Documents\Rafa\UTESM\UltimoTrimestre\Proyecto integrador\Repository\.env\lib\site-packages\office365\runtime\auth\authentication_context.py:249, in AuthenticationContext.authenticate_request(self, request)
#     247 if self._authenticate is None:
#     248     raise ValueError("Authentication credentials are missing or invalid")
# --> 249 self._authenticate(request)
#
# File c:\Users\rafap\Documents\Rafa\UTESM\UltimoTrimestre\Proyecto integrador\Repository\.env\lib\site-packages\office365\runtime\auth\authentication_context.py:222, in AuthenticationContext.acquire_token_for_user.<locals>._authenticate(request)
#     221 def _authenticate(request):
# --> 222     provider.authenticate_request(request)
#
# File c:\Users\rafap\Documents\Rafa\UTESM\UltimoTrimestre\Proyecto integrador\Repository\.env\lib\site-packages\office365\runtime\auth\providers\saml_token_provider.py:85, in SamlTokenProvider.authenticate_request(self, request)
#      81 """
#      82 Authenticate request handler
#      83 """
#      84 logger = self.logger(self.authenticate_request.__name__)
# ---> 85 self.ensure_authentication_cookie()
#      86 logger.debug_secrets(self._cached_auth_cookies)
#      87 cookie_header_value = "; ".join(
#      88     [
#      89         "=".join([key, str(val)])
#      90         for key, val in self._cached_auth_cookies.items()
#      91     ]
#      92 )
#
# File c:\Users\rafap\Documents\Rafa\UTESM\UltimoTrimestre\Proyecto integrador\Repository\.env\lib\site-packages\office365\runtime\auth\providers\saml_token_provider.py:97, in SamlTokenProvider.ensure_authentication_cookie(self)
#      95 def ensure_authentication_cookie(self):
#      96     if self._cached_auth_cookies is None:
# ---> 97         self._cached_auth_cookies = self.get_authentication_cookie()
#      98     return True
#
# File c:\Users\rafap\Documents\Rafa\UTESM\UltimoTrimestre\Proyecto integrador\Repository\.env\lib\site-packages\office365\runtime\auth\providers\saml_token_provider.py:112, in SamlTokenProvider.get_authentication_cookie(self)
#     110     else:
#     111         token = self._acquire_service_token()
# --> 112     return self._get_authentication_cookie(token, user_realm.IsFederated)
#     113 except requests.exceptions.RequestException as e:
#     114     logger.error(e.response.text)
#
# File c:\Users\rafap\Documents\Rafa\UTESM\UltimoTrimestre\Proyecto integrador\Repository\.env\lib\site-packages\office365\runtime\auth\providers\saml_token_provider.py:312, in SamlTokenProvider._get_authentication_cookie(self, security_token, federated)
#     306     self.error = (
#     307         "An error occurred while retrieving auth cookies from {0}".format(
#     308             self._sts_profile.signin_page_url
#     309         )
#     310     )
#     311     logger.error(self.error)
# --> 312     raise ValueError(self.error)
#     313 return cookies
#
# ValueError: An error occurred while retrieving auth cookies from https://tecmx.sharepoint.com/_forms/default.aspx?wa=wsignin1.0

# %%
import base64

def file_to_base64(file_path):
    # Abrir el archivo en modo binario
    with open(file_path, "rb") as file:
        # Leer el contenido del archivo
        file_content = file.read()
        # Convertir el contenido a una cadena Base64
        base64_encoded = base64.b64encode(file_content).decode('utf-8')
    return base64_encoded

file_path = "datos/0035_FNA_FSW_011_2024_Técnico.NetMobile_WI_202624_17dic2024.Firmada.pdf"

# Convertir el archivo a Base64
base64_string = file_to_base64(file_path)

print(base64_string)

with open("archivo_base64.txt", "w") as output_file:
    output_file.write(base64_string)
# Out:
# ...
