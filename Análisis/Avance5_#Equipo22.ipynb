# %% [markdown]
# # Avance 5. Modelo Final
#
# # Respuestas a las preguntas
# 1. **Ensambles: Se generan al menos cuatro modelos, .**
#
#    Se entrenaron 6 modelos
#
#    ![Etiquetado](evidencias_avance_4/ListaModelos.png "Etiquetado")
#
#
# 2. **Selección: Comparar el rendimiento de los modelos obtenido**
#
# Se anotaron las observaciones sobre que puntos fallaba cada modelo:
#
# ![Etiquetado](evidencias_avance_4/ModelosComparacion.png "Etiquetado")
#
# Se realizo una suma de los promedios de Asertividad con cada acta en el testeo del modelo, obteniendo los siguientes resultados:
#
# ![Etiquetado](evidencias_avance_4/Asertividad.png "Etiquetado")
#
#
# 3. **Graficos: Análisis del rendimiento**
#
# El modelo 4 y 5 fue el que mejor resultados, resaltando el 5 por tener un menor error en comparación del análisis con ambos documentos.
# En los primeros modelos falla el etiquetado en unas partes y en otras acierta correctamente.
# En el último modelo, falla en la etiqueta del nombre completo, pero se tiene un mejor rendimiento cuando se analizan ambos documentos.
# Pero se requiere realizar un entrenamiento extra con más documento para que identifique correctamente las etiquetas de los datos donde falla.
#
#
# **Modelo5**
#
# ![Etiquetado](evidencias_avance_4/Model5/Modelo5-Doc83-p1.png "Etiquetado")
# ![Etiquetado](evidencias_avance_4/Model5/Modelo5-Doc83-p2.png "Etiquetado")
#
# **Modelo4**
#
# Documento 76
#
# ![Etiquetado](evidencias_avance_4/Model4/Modelo4-doc76-p1.png "Etiquetado")
# ![Etiquetado](evidencias_avance_4/Model4/Modelo4-doc76-p2.png "Etiquetado")
#
# Documento 83
#
# ![Etiquetado](evidencias_avance_4/Model4/Modelo4-doc83-p1.png "Etiquetado")
# ![Etiquetado](evidencias_avance_4/Model4/Modelo4-doc83-p2.png "Etiquetado")
#
# **Modelo3**
#
# Documento 76
#
# ![Etiquetado](evidencias_avance_4/Model3/Modelo3-Doc76-p1.png "Etiquetado")
# ![Etiquetado](evidencias_avance_4/Model3/Modelo3-Doc76-p2.png "Etiquetado")
#
# Documento 83
#
# ![Etiquetado](evidencias_avance_4/Model3/Modelo3-Doc83-p1.png "Etiquetado")
#
# **Modelo2**
#
# Documento 76
#
# ![Etiquetado](evidencias_avance_4/Model2/Modelo2-Doc76-p1.png "Etiquetado")
# ![Etiquetado](evidencias_avance_4/Model2/Modelo2-Doc76-p2.png "Etiquetado")
#
# Documento 83
#
# ![Etiquetado](evidencias_avance_4/Model2/Modelo2-Doc83-p1.png "Etiquetado")
# ![Etiquetado](evidencias_avance_4/Model2/Modelo2-Doc83-p2.png "Etiquetado")
#
# **Modelo1**
#
# Documento 76
#
# ![Etiquetado](evidencias_avance_4/Model1/Modelo1-Doc76-p1.png "Etiquetado")
# ![Etiquetado](evidencias_avance_4/Model1/Modelo1-Doc76-p2.png "Etiquetado")
#
# Documento 83
#
# ![Etiquetado](evidencias_avance_4/Model1/Modelo1-Doc83-p1.png "Etiquetado")
# ![Etiquetado](evidencias_avance_4/Model1/Modelo1-Doc83-p2.png "Etiquetado")
#
#
# 4. **Ajustar los dos mejores modelos.**
#
# Se agrego otro documento, 060 y se reetiqueto con otro Documento el 83
#
# ![Etiquetado](evidencias_avance_4/Etiquetado/Mod5-Doc60-p1.png "Etiquetado")
# ![Etiquetado](evidencias_avance_4/Etiquetado/Mod5-Doc83-p1.png "Etiquetado")
#
#
# 5. **Elegir el modelo individual final.**

# %% [markdown]
# Se ha elegido el modelo 5, el cual será presentado con el cliente, el cual va a poder acceder a el atreves de una API con llave.
# Del lado del cliente, estará implantando la consulta a través de un PowerAutomate para que su integración y accesibilidad se con mayor facilidad a como lo requiera dentro de su organización
